# %% [markdown]
# # Partiel de data visualisation
#
# importation des librairis et de la base de données

# %%
import pandas as pd
#import datetime as dt
import seaborn as sns
import numpy as np
sns.set(rc={'figure.figsize':(17,15)})

df = pd.read_csv('dataset.csv')

# %%
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7       1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8       1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9        100004195  STUDIO IN THE SKY - A Documentary Feature Film...
# 10       100004721                                Of Jesus and Madmen
# 11       100005484                                   Lisa Lim New CD!
# ...

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
df.tail()
# Out:
#                ID                                               name  \
# 378656  999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657  999977640                                          The Tribe
# 378658  999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659  999987933                           BioDefense Education Kit
# 378660  999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# 378656      Documentary  Film & Video      USD  2014-10-17  50000.0
# 378657   Narrative Film  Film & Video      USD  2011-07-19   1500.0
# 378658   Narrative Film  Film & Video      USD  2010-08-16  15000.0
# 378659       Technology    Technology      USD  2016-02-13  15000.0
# 378660  Performance Art           Art      USD  2011-08-16   2000.0
#
#                    launched  pledged     state  backers country  usd pledged  \
# ...

# %%
df.describe()
# Out:
#                  ID          goal       pledged        backers   usd pledged  \
# count  3.786610e+05  3.786610e+05  3.786610e+05  378661.000000  3.748640e+05
# mean   1.074731e+09  4.908079e+04  9.682979e+03     105.617476  7.036729e+03
# std    6.190862e+08  1.183391e+06  9.563601e+04     907.185035  7.863975e+04
# min    5.971000e+03  1.000000e-02  0.000000e+00       0.000000  0.000000e+00
# 25%    5.382635e+08  2.000000e+03  3.000000e+01       2.000000  1.698000e+01
# 50%    1.075276e+09  5.200000e+03  6.200000e+02      12.000000  3.947200e+02
# 75%    1.610149e+09  1.600000e+04  4.076000e+03      56.000000  3.034090e+03
# max    2.147476e+09  1.000000e+08  2.033899e+07  219382.000000  2.033899e+07
#
#        usd_pledged_real  usd_goal_real
# count      3.786610e+05   3.786610e+05
# mean       9.058924e+03   4.545440e+04
# std        9.097334e+04   1.152950e+06
# min        0.000000e+00   1.000000e-02
# 25%        3.100000e+01   2.000000e+03
# ...

# %% [markdown]
# # Affichage du nombre de valeurs nulles par colonne

# %%
df.isna().sum()
# Out:
# ID                     0
# name                   4
# category               0
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         3797
# usd_pledged_real       0
# usd_goal_real          0
# dtype: int64

# %% [markdown]
# ## Affichage des types des colonnes

# %%
df.dtypes
# Out:
# ID                    int64
# name                 object
# category             object
# main_category        object
# currency             object
# deadline             object
# goal                float64
# launched             object
# pledged             float64
# state                object
# backers               int64
# country              object
# usd pledged         float64
# usd_pledged_real    float64
# usd_goal_real       float64
# dtype: object

# %% [markdown]
# ## État des projets présents dans la base de données

# %%
df['state'].value_counts(sort="F").plot.pie(figsize=(20, 20))

# %% [markdown]
# ## Nombre de projet par pays
# ### échelle normale

# %%
df1=pd.value_counts(df["country"])
df1.plot.bar(rot=0,figsize=(20, 10),title='Nombre de projets pas pays',fontsize=20)

# %% [markdown]
# Un pays inconnu apparait on le rennome

# %%
df['country']=df['country'].str.replace('N,0"','unknow')
df1=pd.value_counts(df["country"])

# %% [markdown]
# ### échelle logarithmique

# %%
df1.plot.bar(rot=0,figsize=(20, 10),title='Nombre de projets pas pays echelle logarithmique',fontsize=20,logy=True)

# %% [markdown]
# valeures médianne, moyenne, minimum, et maximum par pays :

# %%
df.groupby("country").goal.agg(["median","mean","min","max"])
# Out:
#             median          mean       min          max
# country
# AT         10000.0  3.982814e+04     10.00    1500000.0
# AU          8000.0  7.238104e+04      1.00  100000000.0
# BE          6500.0  3.344298e+04      1.00    1500000.0
# CA          7000.0  5.459354e+04      1.00  100000000.0
# CH         15000.0  2.628623e+05     20.00  100000000.0
# DE          9900.0  6.833548e+04      1.00  100000000.0
# DK         35000.0  2.393327e+05      5.00  100000000.0
# ES          6000.0  4.714836e+04      1.00   15000000.0
# FR          8500.0  7.299917e+04      1.00  100000000.0
# GB          3000.0  2.814915e+04      1.00  100000000.0
# HK         70000.0  1.859455e+05     10.00    6000000.0
# IE          6000.0  4.248108e+04     15.00   10000000.0
# IT         10000.0  7.014150e+04      1.00   40000000.0
# JP       1000000.0  1.876522e+06  34000.00   12000000.0
# LU          9750.0  3.045152e+04    100.00     500000.0
# MX         60000.0  2.805255e+05     10.00  100000000.0
# ...

# %% [markdown]
# ## Objectifs moyens et valeures moyennes atteintes par pays pour les projets réussis

# %%
df11=df[df['state']=='successful'].groupby("country").usd_goal_real.mean()
df12=df[df['state']=='successful'].groupby("country").usd_pledged_real.mean()
df13= pd.DataFrame({'usd_goal_mean': df11,'usd_pledged_real_mean': df12}, index=df12.index)
df13.plot.bar(rot=0,figsize=(20, 10),title="Tableau comparant les moyennes des objectifs et les moyennes des sommes obtenues par pays pour les projets réussis")

# %%
df21=df[df['state']=='successful'].groupby("country")/int(df.groupby('country').size()
df21.plot.bar(rot=0,figsize=(20, 10))
# Out:
#   File "<ipython-input-14-47fd50f40fd4>", line 2
#     df21.plot.bar(rot=0,figsize=(20, 10))
#        ^
# SyntaxError: invalid syntax

# %%
sns.set(rc={'figure.figsize':(20,100)})
sns.boxplot(x='usd_pledged_real',y='category',data=df).set_title('diagramme en boîte des sommes levées par catégories')
# Out:
# Text(0.5,1,'diagramme en boîte des sommes levées par catégories')

# %%
sns.set(rc={'figure.figsize':(20,30)})
sns.boxplot(x='usd_pledged_real',y='country',data=df).set_title('diagramme en boîte des sommes levées par pays')
sns.set(rc={'figure.figsize':(17,15)})

# %% [markdown]
# On remarque que certains pays et certaine  catdegories et certains pays sont plus généreux ou ont des projets plus couteux
#
# # Heat des différentes variables pour rechercher une corrélation

# %%
sns.heatmap(df.corr(),annot=True)

# %%
sns.heatmap(df[['usd_goal_real','pledged','backers','usd pledged','usd_pledged_real']].corr(),annot=True)

# %%
df1=df[['backers','usd_pledged_real']].head(10)
sns.pairplot(df1,hue='usd_pledged_real')

# %% [markdown]
# # Etude du temps par projet
#
# Création d'un nouvelle colonne

# %%
df['deadline'] = pd.to_datetime(df.deadline, format='%Y-%m-%d')
df['launched'] = pd.to_datetime(df.launched, format='%Y-%m-%d %H:%M:%S')
df['diff_days'] = df['deadline'] - df['launched']
df['diff_days']=df['diff_days']/np.timedelta64(1,'D')

df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline     goal  \
# 0          Poetry    Publishing      GBP 2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD 2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD 2013-02-26  45000.0
# 3           Music         Music      USD 2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD 2015-08-29  19500.0
#
#              launched  pledged     state  backers country  usd pledged  \
# 0 2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
print("Delais moyen pour les projets qui ont echoués",df[df["state"]=="failed"].diff_days.mean())
print("Delais moyen pour les projets qui ont réussis",df[df["state"]=="successful"].diff_days.mean())
# Out:
# Delais moyen pour les projets qui ont echoués 34.61037611019677
# Delais moyen pour les projets qui ont réussis 31.587185905277124

# %%
df3=df[df["state"]=="failed"].groupby("category").diff_days.mean()-df[df["state"]=="successful"].groupby("category").diff_days.mean()

# %% [markdown]
# ## Nombre de projets lancés par mois

# %%
df.groupby(df.launched.dt.month).size().plot.bar(title="Nombre de projets lancés par mois")

# %% [markdown]
# # Don Moyen par projet

# %%
df['arevage_donation'] = df['usd_pledged_real'] /df['backers']
df['arevage_donation'].fillna(0, inplace=True)
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7       1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8       1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9        100004195  STUDIO IN THE SKY - A Documentary Feature Film...
# 10       100004721                                Of Jesus and Madmen
# 11       100005484                                   Lisa Lim New CD!
# ...

# %% [markdown]
# ## Donation median par pays

# %%
df2=df.groupby("country").arevage_donation.median()
df2.plot.bar(figsize=(20, 10),title='Donation median par pays',fontsize=20)

# %% [markdown]
# ## Donation median par catégories

# %%
df3=df.groupby("category").arevage_donation.median()
df3.plot.barh(figsize=(20, 100),title='Donation median par category',fontsize=20)

# %% [markdown]
# ## Donation median par mois

# %%
df3=df.groupby(df.launched.dt.month).arevage_donation.median()
df3.plot.bar(figsize=(20, 20),title='Donation median en fonction des mois',fontsize=20)

# %% [markdown]
# on se rend compte que les gens dépensent moins l'été et fin d'année

# %%
df3=df.groupby(df.launched.dt.year).arevage_donation.median()
df3.plot.bar(figsize=(20, 20),title='Donation median en fonction des mois',fontsize=20)

# %%
df.launched.dt.year.sort_values(ascending=True).head(10)
# Out:
# 247913    1970
# 75397     1970
# 273779    1970
# 2842      1970
# 319002    1970
# 94579     1970
# 48147     1970
# 377716    2009
# 38188     2009
# 18467     2009
# Name: launched, dtype: int64

# %% [markdown]
# Certaines valeures pour les date sont abairantes
